# %%
try:
    import streamlit
except:
    # %pip install streamlit

# %%
try:
    import mplfinance
except:
    # %pip install mplfinance

# %%
# pip install streamlit pandas numpy matplotlib mplfinance

# %%
# streamlit run app.py

# %%
# end
