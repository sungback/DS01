# %%
# 헬로우 월드 예제, 주석 : 사람을 위한 설명
print("hello world") # 함수, 동사(목적어), open the window, "안녕".출력()
# Out:
# hello world

# %%
# 변수 선언
a = 10

# %%
print(a)
# Out:
# 10

# %%
a # cell 의 마지막 라인에 변수가 있으면 자동 출력됨
# Out:
# 10

# %%
# end
