# %%
import random
cnt = 0
while cnt < 5:
  lotto = sorted(random.sample(range(1,46),6))
  if 130 <= sum(lotto) <= 200:
    print(lotto, 'hap=', sum(lotto))
    cnt += 1
# Out:
# [7, 10, 30, 31, 36, 44] hap= 158
# [17, 23, 26, 32, 33, 35] hap= 166
# [9, 16, 23, 42, 43, 44] hap= 177
# [11, 12, 17, 42, 44, 45] hap= 171
# [12, 13, 16, 17, 31, 41] hap= 130
